# %%
#code to add column for day of year
import pandas as pd
import numpy as np
flights = pd.read_csv('flightsbyWW.csv')
flights = pd.DataFrame(flights)

# %%
flights.head()
# Out:
#    Unnamed: 0  index  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0           0      0  2015      1    1            4      AS             98
# 1           1      1  2015      1    1            4      AA           2336
# 2           2      2  2015      1    1            4      US            840
# 3           3      3  2015      1    1            4      AA            258
# 4           4      4  2015      1    1            4      AS            135
#
#   TAIL_NUMBER ORIGIN_AIRPORT ... ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0      N407AS            ANC ...         -22.0         0          0
# 1      N3KUAA            LAX ...          -9.0         0          0
# 2      N171US            SFO ...           5.0         0          0
# 3      N3HYAA            LAX ...          -9.0         0          0
# 4      N527AS            SEA ...         -21.0         0          0
#
#    CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# ...

# %%
flights2 = flights[['DAY_OF_WEEK','AIRLINE', 'FLIGHT_NUMBER', 'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'ARRIVAL_DELAY', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'WW']].copy()

# %%
flights2['DAY_COUNT'] = 0
flights2.head()
# Out:
#    DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0            4      AS             98      N407AS            ANC
# 1            4      AA           2336      N3KUAA            LAX
# 2            4      US            840      N171US            SFO
# 3            4      AA            258      N3HYAA            LAX
# 4            4      AS            135      N527AS            SEA
#
#   DESTINATION_AIRPORT  ARRIVAL_DELAY  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 0                 SEA          -22.0               NaN             NaN
# 1                 PBI           -9.0               NaN             NaN
# 2                 CLT            5.0               NaN             NaN
# 3                 MIA           -9.0               NaN             NaN
# 4                 ANC          -21.0               NaN             NaN
#
#    AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  WW  DAY_COUNT
# 0            NaN                  NaN            NaN   1          0
# ...

# %%
import time
tim = time.time()
day = 1
for i,row in flights2.iterrows():
    flights2.set_value(i,'DAY_COUNT',day)
    if flights2.loc[i,'DAY_OF_WEEK'] != flights2.loc[i+1,'DAY_OF_WEEK']:
        day = day + 1
    else:
        continue
print "Time to run code is ", (time.time() - tim)/60, "minutes"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-6d5716ba58ab> in <module>()
#       4 for i,row in flights2.iterrows():
#       5     flights2.set_value(i,'DAY_COUNT',day)
# ----> 6     if flights2.loc[i,'DAY_OF_WEEK'] != flights2.loc[i+1,'DAY_OF_WEEK']:
#       7         day = day + 1
#       8     else:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     794     def _getitem_tuple(self, tup):
#     795         try:
# --> 796             return self._getitem_lowerdim(tup)
#     797         except IndexingError:
# ...

# %%
flights2.tail()
# Out:
#          DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 5714003            4      B6            688      N657JB            LAX
# 5714004            4      B6            745      N828JB            JFK
# 5714005            4      B6           1503      N913JB            JFK
# 5714006            4      B6            333      N527JB            MCO
# 5714007            4      B6            839      N534JB            JFK
#
#         DESTINATION_AIRPORT  ARRIVAL_DELAY  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 5714003                 BOS          -26.0               NaN             NaN
# 5714004                 PSE          -16.0               NaN             NaN
# 5714005                 SJU           -8.0               NaN             NaN
# 5714006                 SJU          -10.0               NaN             NaN
# 5714007                 BQN            2.0               NaN             NaN
#
#          AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  WW  DAY_COUNT
# ...

# %%
import time
tim = time.time()
print "Time to run code is ", time.time() - tim, "seconds"
# Out:
# Time to run code is  0.000453948974609 seconds

# %%
import pandas as pd
import numpy as np
flights4 = pd.read_csv('flightsbyWWpart2.csv')
flights4 = pd.DataFrame(flights4)

# %%
flights4.tail()
# Out:
#          Unnamed: 0  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5714003     5714003            4      B6            688      N657JB
# 5714004     5714004            4      B6            745      N828JB
# 5714005     5714005            4      B6           1503      N913JB
# 5714006     5714006            4      B6            333      N527JB
# 5714007     5714007            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  ARRIVAL_DELAY  AIR_SYSTEM_DELAY  \
# 5714003            LAX                 BOS          -26.0               NaN
# 5714004            JFK                 PSE          -16.0               NaN
# 5714005            JFK                 SJU           -8.0               NaN
# 5714006            MCO                 SJU          -10.0               NaN
# 5714007            JFK                 BQN            2.0               NaN
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# ...
