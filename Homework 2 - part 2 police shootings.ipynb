# %% [markdown]
# # DS-SF-32 | Homework 02: The `pandas` Library

# %% [markdown]
# In this homework, we will be exploring the `police shootings` dataset using `pandas`.

# %%
import pandas as pd

# %%
killings = pd.read_csv('C:\GIT\DS-SF-32\dataset/police-killings.csv')
killings.head()
# Out:
#    Unnamed: 0                name  age gender    raceethnicity     month  day  \
# 0           0  A'donte Washington   16   Male            Black  February   23
# 1           1      Aaron Rutledge   27   Male            White     April    2
# 2           2         Aaron Siler   26   Male            White     March   14
# 3           3        Aaron Valdez   25   Male  Hispanic/Latino     March   11
# 4           4        Adam Jovicic   29   Male            White     March   19
#
#    year           streetaddress          city state  \
# 0  2015            Clearview Ln     Millbrook    AL
# 1  2015  300 block Iris Park Dr     Pineville    LA
# 2  2015    22nd Ave and 56th St       Kenosha    WI
# 3  2015       3000 Seminole Ave    South Gate    CA
# 4  2015          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# ...

# %% [markdown]
# #### A) Starter question: Display a few lines of the dataset to the screen.

# %%
killings.head()
# Out:
#    Unnamed: 0                name  age gender    raceethnicity     month  day  \
# 0           0  A'donte Washington   16   Male            Black  February   23
# 1           1      Aaron Rutledge   27   Male            White     April    2
# 2           2         Aaron Siler   26   Male            White     March   14
# 3           3        Aaron Valdez   25   Male  Hispanic/Latino     March   11
# 4           4        Adam Jovicic   29   Male            White     March   19
#
#    year           streetaddress          city state  \
# 0  2015            Clearview Ln     Millbrook    AL
# 1  2015  300 block Iris Park Dr     Pineville    LA
# 2  2015    22nd Ave and 56th St       Kenosha    WI
# 3  2015       3000 Seminole Ave    South Gate    CA
# 4  2015          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# ...

# %% [markdown]
# #### 1. Make the following changed to column names:
#
# + lawenforcementagency -> agency
# + raceethnicity        -> race

# %%
killings.rename(columns = {'lawenforcementagency':'agency'}, inplace = True)
killings.rename(columns = {'raceethnicity':'race'}, inplace = True)
killings.head()
# Out:
#    Unnamed: 0                name  age gender             race     month  day  \
# 0           0  A'donte Washington   16   Male            Black  February   23
# 1           1      Aaron Rutledge   27   Male            White     April    2
# 2           2         Aaron Siler   26   Male            White     March   14
# 3           3        Aaron Valdez   25   Male  Hispanic/Latino     March   11
# 4           4        Adam Jovicic   29   Male            White     March   19
#
#    year           streetaddress          city state  \
# 0  2015            Clearview Ln     Millbrook    AL
# 1  2015  300 block Iris Park Dr     Pineville    LA
# 2  2015    22nd Ave and 56th St       Kenosha    WI
# 3  2015       3000 Seminole Ave    South Gate    CA
# 4  2015          364 Hiwood Ave  Munroe Falls    OH
#
#                             agency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# ...

# %% [markdown]
# #### 2. Show the count of missing values in each column

# %%
killings.isnull().sum()
# Out:
# Unnamed: 0       0
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# #### 3. replace each null value in the dataframe with the string "Unknown"

# %%
killings.fillna(value='Unknown')
# Out:
#      Unnamed: 0                     name  age  gender             race  \
# 0             0       A'donte Washington   16    Male            Black
# 1             1           Aaron Rutledge   27    Male            White
# 2             2              Aaron Siler   26    Male            White
# 3             3             Aaron Valdez   25    Male  Hispanic/Latino
# 4             4             Adam Jovicic   29    Male            White
# 5             5            Adam Reinhart   29    Male            White
# 6             6         Adrian Hernandez   22    Male  Hispanic/Latino
# 7             7             Adrian Solis   35    Male  Hispanic/Latino
# 8             8            Alan Alverson   44    Male            White
# 9             9               Alan James   31    Male            White
# 10           10         Albert Hanson Jr   76    Male            White
# 11           11           Alec Ouzounian   40    Male            White
# ...

# %% [markdown]
# #### 4. How many killings were there so far in 2015?

# %%
killings['year'].unique()
print killings.shape
print "There have been 467 killings in 2015 so far"
# Out:
# (467, 15)
# There have been 467 killings in 2015 so far

# %% [markdown]
# #### 5. Of all killings, how many were male and how many female?

# %%
print killings['gender'].value_counts()
print "There have been 445 male killing and 22 female killings"
killings['armed'].count()
# Out:
# Male      445
# Female     22
# Name: gender, dtype: int64
# There have been 445 male killing and 22 female killings
# 467

# %% [markdown]
# #### 6. How many killings were of unarmed people?

# %%
killings['armed'].value_counts()
clue = killings.copy()
clue = clue[clue['armed'] == 'No'] 
print "The total killings of unarmed people is ", clue['armed'].count()
# Out:
# The total killings of unarmed people is  102

# %% [markdown]
# #### 7. What percentage of all killings were unarmed?

# %%
a = float(clue['armed'].count())
b = float(killings['armed'].count())
print "print percent of unarmed killings is ", (a/b)*100
# Out:
# print percent of unarmed killings is  21.8415417559

# %% [markdown]
# #### 8. What are the 5 states with the most killings?

# %%
print killings['state'].value_counts().head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %% [markdown]
# #### 9. Show a value counts of deaths for each race

# %%
print killings['race'].value_counts()
# Out:
# White                     236
# Black                     135
# Hispanic/Latino            67
# Unknown                    15
# Asian/Pacific Islander     10
# Native American             4
# Name: race, dtype: int64

# %% [markdown]
# #### 10. Display a histogram of ages of all killings

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.hist(killings['age'], bins=10)
# Out:
# <img src="data:image/png;base64,...">
# (array([  58.,   98.,  114.,   76.,   51.,   36.,   21.,    7.,    4.,    2.]),
#  array([ 16. ,  23.1,  30.2,  37.3,  44.4,  51.5,  58.6,  65.7,  72.8,
#          79.9,  87. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 11. Show 6 histograms of ages by race

# %%
killings['age'].hist(by=killings['race'], bins= 6)
# Out:
# <img src="data:image/png;base64,...">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009C20F60>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B36BE48>]], dtype=object)

# %% [markdown]
# #### 12. What is the average age of death by race?

# %%
blue = killings['race'].unique().tolist()
print blue
pen = killings.copy()
for word in blue:
    pen = pen[pen['race'] == word]
    print "Average for ", word, "is ", pen['age'].mean()
    pen = killings.copy()
# Out:
# ['Black', 'White', 'Hispanic/Latino', 'Unknown', 'Asian/Pacific Islander', 'Native American']
# Average for  Black is  34.0444444444
# Average for  White is  40.4661016949
# Average for  Hispanic/Latino is  31.7164179104
# Average for  Unknown is  43.5333333333
# Average for  Asian/Pacific Islander is  40.8
# Average for  Native American is  27.75

# %% [markdown]
# #### 13. Show a bar chart with counts of deaths every month

# %%
fig = plt.figure()
killings['month'].value_counts().plot(kind='bar')
#still need to figure out how to sort the bars in increasing order of month
# Out:
# <img src="data:image/png;base64,...">
